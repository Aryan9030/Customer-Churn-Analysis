# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Load Dataset
df = pd.read_csv(r"C:\Users\aryan\OneDrive\Desktop\Customer-Churn-Analysis\data\customer_churn.csv")

# Display First Five Rows
print("First 5 Rows:")
print(df.head())

# Dataset Information
print("\nDataset Info:")
print(df.info())

# Missing Values
print("\nMissing Values:")
print(df.isnull().sum())

# Remove Duplicates
df = df.drop_duplicates()

# Remove Extra Spaces from Column Names
df.columns = df.columns.str.strip()

# Display Column Names
print("\nColumns:")
print(df.columns)

# Create Screenshots Folder
os.makedirs("screenshots", exist_ok=True)

# Check if required columns exist
print(df.columns.tolist())
# Out:
# First 5 Rows:
#    CustomerID  tenure  MonthlyCharges Churn
# 0           1      12            45.5    No
# 1           2       3            85.0   Yes
# 2           3      24            60.0    No
# 3           4       2            95.0   Yes
# 4           5      36            55.0    No
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      10 non-null     int64
#  1   tenure          10 non-null     int64
#  2   MonthlyCharges  10 non-null     float64
#  3   Churn           10 non-null     object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 452.0+ bytes
# None
#
# Missing Values:
# CustomerID        0
# tenure            0
# MonthlyCharges    0
# Churn             0
# dtype: int64
#
# Columns:
# Index(['CustomerID', 'tenure', 'MonthlyCharges', 'Churn'], dtype='object')
# ['CustomerID', 'tenure', 'MonthlyCharges', 'Churn']
